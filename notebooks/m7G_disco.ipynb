# %%
import numpy as np
import modisco
from importlib import reload
from collections import OrderedDict

import warnings
warnings.filterwarnings('ignore')

# %%
data_dir = '/data/m7G/data_for_mil/explain/'

task_to_scores = OrderedDict()
task_to_hyp_scores = OrderedDict()
task_to_scores['m7G'] = np.load(data_dir + 'shuffle_task_to_scores.npy', allow_pickle=True)
task_to_hyp_scores['m7G'] = np.load(data_dir + 'shuffle_task_to_hyp_scores.npy', allow_pickle=True)
onehot_data = np.load(data_dir + 'shuffle_onehot_data.npy', allow_pickle=True)

# %%
import modisco.visualization
from modisco.visualization import viz_sequence

viz_sequence.plot_weights(task_to_scores['m7G'][1], subticks_frequency=5)
viz_sequence.plot_weights(task_to_hyp_scores['m7G'][1], subticks_frequency=5)
viz_sequence.plot_weights(onehot_data[1], subticks_frequency=5)

# %%
null_per_pos_scores = modisco.coordproducers.LaplaceNullDist(num_to_samp=5000)
tfmodisco_results = modisco.tfmodisco_workflow.workflow.TfModiscoWorkflow(
                    #Slight modifications from the default settings
                    sliding_window_size=7,
                    flank_size=3,
                    target_seqlet_fdr=0.15,
                    seqlets_to_patterns_factory=
                     modisco.tfmodisco_workflow.seqlets_to_patterns.TfModiscoSeqletsToPatternsFactory(
                        trim_to_window_size=7,
                        initial_flank_to_add=3,
                        kmer_len=8, num_gaps=3,
                        num_mismatches=2,
                        final_min_cluster_size=30)
                )(
                 task_names=["m7G"],
                 contrib_scores=task_to_scores,
                 hypothetical_contribs=task_to_hyp_scores,
                 one_hot=onehot_data,
                 null_per_pos_scores = null_per_pos_scores,
                 revcomp=False
)
# Out:
# MEMORY 0.343801856
# On task m7G
# Computing windowed sums on original
# Generating null dist
# peak(mu)= 4.545998954506215e-11
# Computing threshold
# Thresholds from null dist were -1.2946640646550355e-09  and  1.606602017720747e-09
# Final raw thresholds are -1.2946640646550355e-09  and  1.606602017720747e-09
# Final transformed thresholds are -0.9404320744303398  and  0.958537018055665
# Got 915 coords
# After resolving overlaps, got 915 seqlets
# Across all tasks, the weakest transformed threshold used was: 0.9403320744303398
# MEMORY 0.35424256
# 915 identified in total
# 2 activity patterns with support >= 100 out of 3 possible patterns
# Metacluster sizes:  [683, 232]
# Idx to activities:  {0: '1', 1: '-1'}
# MEMORY 0.35424256
# On metacluster 1
# Metacluster size 232
# Relevant tasks:  ('m7G',)
# Relevant signs:  (-1,)
# WARNING:tensorflow:From /home/daiyun/myenv/disco/lib/python3.6/site-packages/modisco/backend/tensorflow_backend.py:87: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# TfModiscoSeqletsToPatternsFactory: seed=1234
# (Round 1) num seqlets: 232
# (Round 1) Computing coarse affmat
# MEMORY 0.400211968
# Beginning embedding computation
# Computing embeddings
# MAKING A SESSION
# WARNING:tensorflow:From /home/daiyun/myenv/disco/lib/python3.6/site-packages/modisco/backend/tensorflow_backend.py:19: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/daiyun/myenv/disco/lib/python3.6/site-packages/modisco/backend/tensorflow_backend.py:20: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# Finished embedding computation in 0.54 s
# Starting affinity matrix computations
# Normalization computed in 0.11 s
# Cosine similarity mat computed in 0.16 s
# Finished affinity matrix computations in 0.16 s
# (Round 1) Compute nearest neighbors from coarse affmat
# MEMORY 0.727666688
# Computed nearest neighbors in 0.02 s
# MEMORY 0.727666688
# (Round 1) Computing affinity matrix on nearest neighbors
# MEMORY 0.727666688
# Launching nearest neighbors affmat calculation job
# MEMORY 0.727666688
# Parallel runs completed
# MEMORY 0.73367552
# Job completed in: 0.31 s
# MEMORY 0.73367552
# (Round 1) Computed affinity matrix on nearest neighbors in 0.35 s
# MEMORY 0.73367552
# Filtered down to 232 of 232
# (Round 1) Retained 232 rows out of 232 after filtering
# MEMORY 0.73367552
# (Round 1) Computing density adapted affmat
# MEMORY 0.73367552
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 232 samples in 0.000s...
# [t-SNE] Computed neighbors for 232 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 232 / 232
# [t-SNE] Mean sigma: 0.312913
# (Round 1) Computing clustering
# MEMORY 0.73367552
# Beginning preprocessing + Leiden
#   0%|          | 0/50 [00:00<?, ?it/s]
# Quality: 0.676841302661641
# Quality: 0.677859771244398
# 100%|██████████| 50/50 [00:01<00:00, 49.49it/s]
# Got 7 clusters after round 1
# Counts:
# {2: 39, 1: 43, 3: 30, 0: 50, 4: 30, 5: 22, 6: 18}
# MEMORY 0.73367552
# (Round 1) Aggregating seqlets in each cluster
# MEMORY 0.73367552
# Aggregating for cluster 0 with 50 seqlets
# MEMORY 0.73367552
# Trimmed 7 out of 50
# Skipped 11 seqlets
# Aggregating for cluster 1 with 43 seqlets
# MEMORY 0.734978048
# Trimmed 5 out of 43
# Skipped 10 seqlets
# Aggregating for cluster 2 with 39 seqlets
# MEMORY 0.734978048
# Trimmed 3 out of 39
# Skipped 4 seqlets
# Aggregating for cluster 3 with 30 seqlets
# MEMORY 0.734978048
# Trimmed 4 out of 30
# Skipped 12 seqlets
# Aggregating for cluster 4 with 30 seqlets
# MEMORY 0.734978048
# Trimmed 1 out of 30
# Skipped 10 seqlets
# Aggregating for cluster 5 with 22 seqlets
# MEMORY 0.734978048
# Trimmed 3 out of 22
# Skipped 10 seqlets
# Aggregating for cluster 6 with 18 seqlets
# MEMORY 0.734978048
# Trimmed 0 out of 18
# (Round 2) num seqlets: 152
# (Round 2) Computing coarse affmat
# MEMORY 0.734978048
# Beginning embedding computation
# Computing embeddings
# Finished embedding computation in 0.18 s
# Starting affinity matrix computations
# Normalization computed in 0.07 s
# Cosine similarity mat computed in 0.1 s
# Finished affinity matrix computations in 0.1 s
# (Round 2) Compute nearest neighbors from coarse affmat
# MEMORY 0.762834944
# Computed nearest neighbors in 0.01 s
# MEMORY 0.762834944
# (Round 2) Computing affinity matrix on nearest neighbors
# MEMORY 0.762834944
# Launching nearest neighbors affmat calculation job
# MEMORY 0.762834944
# Parallel runs completed
# MEMORY 0.764514304
# Job completed in: 0.21 s
# MEMORY 0.764514304
# (Round 2) Computed affinity matrix on nearest neighbors in 0.24 s
# MEMORY 0.764514304
# Not applying filtering for rounds above first round
# MEMORY 0.764514304
# (Round 2) Computing density adapted affmat
# MEMORY 0.764514304
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 152 samples in 0.000s...
# [t-SNE] Computed neighbors for 152 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 152 / 152
# [t-SNE] Mean sigma: 0.339637
# (Round 2) Computing clustering
# MEMORY 0.764514304
# Beginning preprocessing + Leiden
#   0%|          | 0/50 [00:00<?, ?it/s]
# Quality: 0.6959129800179956
# 100%|██████████| 50/50 [00:00<00:00, 115.01it/s]
# Got 6 clusters after round 2
# Counts:
# {0: 42, 2: 28, 1: 32, 3: 21, 4: 18, 5: 11}
# MEMORY 0.764514304
# (Round 2) Aggregating seqlets in each cluster
# MEMORY 0.764514304
# Aggregating for cluster 0 with 42 seqlets
# MEMORY 0.764514304
# Trimmed 1 out of 42
# Skipped 4 seqlets
# Removed 2 duplicate seqlets
# Aggregating for cluster 1 with 32 seqlets
# MEMORY 0.764514304
# Trimmed 7 out of 32
# Dropping cluster 1 with 25 seqlets due to sign disagreement
# Aggregating for cluster 2 with 28 seqlets
# MEMORY 0.764514304
# Trimmed 3 out of 28
# Aggregating for cluster 3 with 21 seqlets
# MEMORY 0.764514304
# Trimmed 3 out of 21
# Aggregating for cluster 4 with 18 seqlets
# MEMORY 0.764514304
# Trimmed 2 out of 18
# Skipped 2 seqlets
# Aggregating for cluster 5 with 11 seqlets
# MEMORY 0.764514304
# Trimmed 3 out of 11
# Got 6 clusters
# Splitting into subclusters...
# MEMORY 0.764514304
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0024945735931396484 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.0116455
# Louvain completed 21 runs in 0.4466738700866699 seconds
# Similarity is 0.4134480238587172; is_dissimilar is True
# Got 2 subclusters
# Merging on 7 clusters
# MEMORY 0.7660544
# On merging iteration 1
# Computing pattern to seqlet distances
# Computing pattern to pattern distances
# Got 7 patterns after merging
# MEMORY 0.766087168
# Performing seqlet reassignment
# MEMORY 0.766087168
# Got 0 patterns after reassignment
# MEMORY 0.766087168
# Total time taken is 4.49s
# MEMORY 0.766087168
# On metacluster 0
# Metacluster size 683
# Relevant tasks:  ('m7G',)
# Relevant signs:  (1,)
# TfModiscoSeqletsToPatternsFactory: seed=1234
# (Round 1) num seqlets: 683
# (Round 1) Computing coarse affmat
# MEMORY 0.801435648
# Beginning embedding computation
# Computing embeddings
# Finished embedding computation in 0.94 s
# Starting affinity matrix computations
# Normalization computed in 0.37 s
# Cosine similarity mat computed in 0.58 s
# Finished affinity matrix computations in 0.58 s
# (Round 1) Compute nearest neighbors from coarse affmat
# MEMORY 0.80822272
# Computed nearest neighbors in 0.09 s
# MEMORY 0.80822272
# (Round 1) Computing affinity matrix on nearest neighbors
# MEMORY 0.80822272
# Launching nearest neighbors affmat calculation job
# MEMORY 0.80822272
# Parallel runs completed
# MEMORY 0.818200576
# Job completed in: 1.33 s
# MEMORY 0.818200576
# (Round 1) Computed affinity matrix on nearest neighbors in 1.4 s
# MEMORY 0.821817344
# Filtered down to 678 of 683
# (Round 1) Retained 678 rows out of 683 after filtering
# MEMORY 0.821878784
# (Round 1) Computing density adapted affmat
# MEMORY 0.82546688
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 678 samples in 0.000s...
# [t-SNE] Computed neighbors for 678 samples in 0.006s...
# [t-SNE] Computed conditional probabilities for sample 678 / 678
# [t-SNE] Mean sigma: 0.260229
# (Round 1) Computing clustering
# MEMORY 0.8292352
# Beginning preprocessing + Leiden
#   0%|          | 0/50 [00:00<?, ?it/s]
# Quality: 0.6430125832464533
#   2%|▏         | 1/50 [00:00<00:05,  8.41it/s]
# Quality: 0.6431394616958387
#   4%|▍         | 2/50 [00:00<00:05,  8.76it/s]
# Quality: 0.6443495076286065
#  44%|████▍     | 22/50 [00:02<00:03,  9.00it/s]
# Quality: 0.644597684155748
#  74%|███████▍  | 37/50 [00:04<00:01,  8.54it/s]
# Quality: 0.6446208233687696
#  76%|███████▌  | 38/50 [00:04<00:01,  7.80it/s]
# Quality: 0.6446234746746402
# 100%|██████████| 50/50 [00:05<00:00,  8.79it/s]
# Got 13 clusters after round 1
# Counts:
# {7: 44, 5: 66, 3: 76, 4: 71, 9: 18, 2: 86, 1: 87, 0: 116, 6: 48, 8: 44, 12: 4, 10: 14, 11: 4}
# MEMORY 0.829763584
# (Round 1) Aggregating seqlets in each cluster
# MEMORY 0.829763584
# Aggregating for cluster 0 with 116 seqlets
# MEMORY 0.829763584
# Trimmed 14 out of 116
# Skipped 16 seqlets
# Aggregating for cluster 1 with 87 seqlets
# MEMORY 0.829763584
# Trimmed 14 out of 87
# Skipped 12 seqlets
# Aggregating for cluster 2 with 86 seqlets
# MEMORY 0.829763584
# Trimmed 5 out of 86
# Skipped 28 seqlets
# Aggregating for cluster 3 with 76 seqlets
# MEMORY 0.829763584
# Trimmed 0 out of 76
# Skipped 34 seqlets
# Aggregating for cluster 4 with 71 seqlets
# MEMORY 0.829763584
# Trimmed 9 out of 71
# Skipped 14 seqlets
# Aggregating for cluster 5 with 66 seqlets
# MEMORY 0.829763584
# Trimmed 10 out of 66
# Skipped 4 seqlets
# Aggregating for cluster 6 with 48 seqlets
# MEMORY 0.829763584
# Trimmed 4 out of 48
# Skipped 17 seqlets
# Aggregating for cluster 7 with 44 seqlets
# MEMORY 0.829763584
# Trimmed 4 out of 44
# Skipped 5 seqlets
# Aggregating for cluster 8 with 44 seqlets
# MEMORY 0.829763584
# Trimmed 3 out of 44
# Skipped 26 seqlets
# Removed 1 duplicate seqlets
# Aggregating for cluster 9 with 18 seqlets
# MEMORY 0.829763584
# Trimmed 3 out of 18
# Skipped 5 seqlets
# Aggregating for cluster 10 with 14 seqlets
# MEMORY 0.829763584
# Trimmed 0 out of 14
# Aggregating for cluster 11 with 4 seqlets
# MEMORY 0.829763584
# Trimmed 0 out of 4
# Aggregating for cluster 12 with 4 seqlets
# MEMORY 0.829763584
# Trimmed 0 out of 4
# Skipped 1 seqlets
# (Round 2) num seqlets: 449
# (Round 2) Computing coarse affmat
# MEMORY 0.829763584
# Beginning embedding computation
# Computing embeddings
# Finished embedding computation in 0.54 s
# Starting affinity matrix computations
# Normalization computed in 0.21 s
# Cosine similarity mat computed in 0.31 s
# Finished affinity matrix computations in 0.31 s
# (Round 2) Compute nearest neighbors from coarse affmat
# MEMORY 0.818806784
# Computed nearest neighbors in 0.08 s
# MEMORY 0.820965376
# (Round 2) Computing affinity matrix on nearest neighbors
# MEMORY 0.820965376
# Launching nearest neighbors affmat calculation job
# MEMORY 0.820965376
# Parallel runs completed
# MEMORY 0.823537664
# Job completed in: 0.82 s
# MEMORY 0.823537664
# (Round 2) Computed affinity matrix on nearest neighbors in 0.87 s
# MEMORY 0.823537664
# Not applying filtering for rounds above first round
# MEMORY 0.823537664
# (Round 2) Computing density adapted affmat
# MEMORY 0.823537664
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 449 samples in 0.000s...
# [t-SNE] Computed neighbors for 449 samples in 0.003s...
# [t-SNE] Computed conditional probabilities for sample 449 / 449
# [t-SNE] Mean sigma: 0.266568
# (Round 2) Computing clustering
# MEMORY 0.823537664
# Beginning preprocessing + Leiden
#   0%|          | 0/50 [00:00<?, ?it/s]
# Quality: 0.649299545591154
#  12%|█▏        | 6/50 [00:00<00:02, 19.08it/s]
# Quality: 0.64935677342225
#  40%|████      | 20/50 [00:01<00:01, 16.94it/s]
# Quality: 0.6493671814830614
# 100%|██████████| 50/50 [00:02<00:00, 17.93it/s]
# Got 10 clusters after round 2
# Counts:
# {0: 87, 1: 67, 8: 13, 2: 63, 9: 11, 5: 47, 3: 53, 4: 50, 6: 43, 7: 15}
# MEMORY 0.823537664
# (Round 2) Aggregating seqlets in each cluster
# MEMORY 0.823537664
# Aggregating for cluster 0 with 87 seqlets
# MEMORY 0.823537664
# Trimmed 3 out of 87
# Skipped 15 seqlets
# Removed 1 duplicate seqlets
# Aggregating for cluster 1 with 67 seqlets
# MEMORY 0.823762944
# Trimmed 3 out of 67
# Skipped 9 seqlets
# Aggregating for cluster 2 with 63 seqlets
# MEMORY 0.823762944
# Trimmed 12 out of 63
# Aggregating for cluster 3 with 53 seqlets
# MEMORY 0.823762944
# Trimmed 4 out of 53
# Aggregating for cluster 4 with 50 seqlets
# MEMORY 0.823762944
# Trimmed 1 out of 50
# Skipped 8 seqlets
# Aggregating for cluster 5 with 47 seqlets
# MEMORY 0.823762944
# Trimmed 2 out of 47
# Removed 1 duplicate seqlets
# Aggregating for cluster 6 with 43 seqlets
# MEMORY 0.823762944
# Trimmed 4 out of 43
# Skipped 1 seqlets
# Aggregating for cluster 7 with 15 seqlets
# MEMORY 0.823762944
# Trimmed 1 out of 15
# Skipped 4 seqlets
# Aggregating for cluster 8 with 13 seqlets
# MEMORY 0.823762944
# Trimmed 1 out of 13
# Aggregating for cluster 9 with 11 seqlets
# MEMORY 0.823762944
# Trimmed 0 out of 11
# Skipped 1 seqlets
# Got 10 clusters
# Splitting into subclusters...
# MEMORY 0.823762944
# Inspecting for spurious merging
# Wrote graph to binary file in 0.009432315826416016 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00760095
# After 2 runs, maximum modularity is Q = 0.0101396
# Louvain completed 22 runs in 0.5330624580383301 seconds
# Similarity is 0.4632698249637113; is_dissimilar is True
# Inspecting for spurious merging
# Wrote graph to binary file in 0.004361391067504883 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00741076
# Louvain completed 21 runs in 0.4991788864135742 seconds
# Similarity is 0.7087263755151975; is_dissimilar is True
# Got 3 subclusters
# Inspecting for spurious merging
# Wrote graph to binary file in 0.006452322006225586 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = -0.0133596
# After 2 runs, maximum modularity is Q = 0.00838426
# After 4 runs, maximum modularity is Q = 0.00838427
# Louvain completed 24 runs in 0.5896577835083008 seconds
# Similarity is 0.7717583048964362; is_dissimilar is True
# Inspecting for spurious merging
# Wrote graph to binary file in 0.002951383590698242 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00390648
# After 3 runs, maximum modularity is Q = 0.00410787
# After 4 runs, maximum modularity is Q = 0.00466351
# After 5 runs, maximum modularity is Q = 0.00512293
# After 13 runs, maximum modularity is Q = 0.00588167
# Louvain completed 33 runs in 0.7835414409637451 seconds
# Similarity is 0.8046686522212009; is_dissimilar is False
# Got 2 subclusters
# Inspecting for spurious merging
# Wrote graph to binary file in 0.003940582275390625 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.0128883
# Louvain completed 21 runs in 0.47858476638793945 seconds
# Similarity is 0.376984475377327; is_dissimilar is True
# Got 2 subclusters
# Inspecting for spurious merging
# Wrote graph to binary file in 0.006936550140380859 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00817145
# Louvain completed 21 runs in 0.48062896728515625 seconds
# Similarity is 0.6787253319310455; is_dissimilar is True
# Got 2 subclusters
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0025942325592041016 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.0192446
# Louvain completed 21 runs in 0.46854734420776367 seconds
# Similarity is 0.27640517466679204; is_dissimilar is True
# Got 2 subclusters
# Inspecting for spurious merging
# Wrote graph to binary file in 0.00318145751953125 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.0118047
# After 4 runs, maximum modularity is Q = 0.0121543
# Louvain completed 24 runs in 0.5474362373352051 seconds
# Similarity is 0.31586277417455166; is_dissimilar is True
# Got 2 subclusters
# Inspecting for spurious merging
# Wrote graph to binary file in 0.003291606903076172 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.0167116
# Louvain completed 21 runs in 0.4688544273376465 seconds
# Similarity is 0.36801123486700144; is_dissimilar is True
# Got 2 subclusters
# Merging on 18 clusters
# MEMORY 0.824373248
# On merging iteration 1
# Computing pattern to seqlet distances
# Computing pattern to pattern distances
# Got 18 patterns after merging
# MEMORY 0.824406016
# Performing seqlet reassignment
# MEMORY 0.824406016
# Cross contin jaccard time taken: 1.5 s
# Discarded 140 seqlets
# Skipped 38 seqlets
# Removed 1 duplicate seqlets
# Skipped 46 seqlets
# Got 1 patterns after reassignment
# MEMORY 0.824467456
# Total time taken is 22.24s
# MEMORY 0.824467456

# %%
import h5py
import modisco.util
reload(modisco.util)
![[ -e results.hdf5 ]] && rm results.hdf5
grp = h5py.File("results.hdf5")
tfmodisco_results.save_hdf5(grp)
grp.close()

# %%
from collections import Counter
from modisco.visualization import viz_sequence
reload(viz_sequence)
from matplotlib import pyplot as plt

import modisco.affinitymat.core
reload(modisco.affinitymat.core)
import modisco.cluster.phenograph.core
reload(modisco.cluster.phenograph.core)
import modisco.cluster.phenograph.cluster
reload(modisco.cluster.phenograph.cluster)
import modisco.cluster.core
reload(modisco.cluster.core)
import modisco.aggregator
reload(modisco.aggregator)

hdf5_results = h5py.File("results.hdf5","r")

print("Metaclusters heatmap")
import seaborn as sns
activity_patterns = np.array(hdf5_results['metaclustering_results']['attribute_vectors'])[
                    np.array(
        [x[0] for x in sorted(
                enumerate(hdf5_results['metaclustering_results']['metacluster_indices']),
               key=lambda x: x[1])])]
sns.heatmap(activity_patterns, center=0)
plt.show()

metacluster_names = [
    x.decode("utf-8") for x in 
    list(hdf5_results["metaclustering_results"]
         ["all_metacluster_names"][:])]

all_patterns = []
background = np.array([0.24, 0.25, 0.25, 0.26])

for metacluster_name in metacluster_names:
    print(metacluster_name)
    metacluster_grp = (hdf5_results["metacluster_idx_to_submetacluster_results"]
                                   [metacluster_name])
    print("activity pattern:",metacluster_grp["activity_pattern"][:])
    all_pattern_names = [x.decode("utf-8") for x in 
                         list(metacluster_grp["seqlets_to_patterns_result"]
                                             ["patterns"]["all_pattern_names"][:])]
    if (len(all_pattern_names)==0):
        print("No motifs found for this activity pattern")
    for pattern_name in all_pattern_names:
        print(metacluster_name, pattern_name)
        all_patterns.append((metacluster_name, pattern_name))
        pattern = metacluster_grp["seqlets_to_patterns_result"]["patterns"][pattern_name]
        print("total seqlets:",len(pattern["seqlets_and_alnmts"]["seqlets"]))
        
        print("onehot, fwd and rev:")
        viz_sequence.plot_weights(viz_sequence.ic_scale(np.array(pattern["sequence"]["fwd"]),
                                                        background=background)) 
        
hdf5_results.close()
# Out:
# Metaclusters heatmap
# metacluster_0
# activity pattern: [1]
# metacluster_0 pattern_0
# total seqlets: 153
# onehot, fwd and rev:
# metacluster_1
# activity pattern: [-1]
# No motifs found for this activity pattern

# %%
import h5py
import numpy as np
import modisco
from modisco.tfmodisco_workflow import workflow

track_set = modisco.tfmodisco_workflow.workflow.prep_track_set(
                task_names=['m7G'],
                contrib_scores=task_to_scores,
                hypothetical_contribs=task_to_hyp_scores,
                one_hot=onehot_data)

grp = h5py.File("results.hdf5","r")
loaded_tfmodisco_results =\
    workflow.TfModiscoResults.from_hdf5(grp, track_set=track_set)
grp.close()

# %%
untrimmed_gata_pattern = (
    loaded_tfmodisco_results
    .metacluster_idx_to_submetacluster_results["metacluster_0"]
    .seqlets_to_patterns_result.patterns[0])
print("Untrimmed Gata - sequence (scaled by information content)")
viz_sequence.plot_weights(viz_sequence.ic_scale(untrimmed_gata_pattern["sequence"].fwd, background=background))
print("Untrimmed Gata - task 0 hypothetical scores")
viz_sequence.plot_weights(untrimmed_gata_pattern["m7G_hypothetical_contribs"].fwd)
trimmed_gata = untrimmed_gata_pattern.trim_by_ic(ppm_track_name="sequence",
                                                 background=background,
                                                 threshold=0.6)
print("IC-trimmed Gata - sequence (scaled by information content)")
viz_sequence.plot_weights(viz_sequence.ic_scale(trimmed_gata["sequence"].fwd, background=background))
# Out:
# Untrimmed Gata - sequence (scaled by information content)
# Untrimmed Gata - task 0 hypothetical scores
# IC-trimmed Gata - sequence (scaled by information content)
